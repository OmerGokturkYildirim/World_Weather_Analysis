# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID             City Country                 Date    Lat     Lng  \
# 0        0           Touros      BR  2020-04-19 03:47:31  -5.20  -35.46
# 1        1  Bambous Virieux      MU  2020-04-19 03:47:31 -20.34   57.76
# 2        2        Jamestown      US  2020-04-19 03:42:46  42.10  -79.24
# 3        3      Yellowknife      CA  2020-04-19 03:47:31  62.46 -114.35
# 4        4          Ushuaia      AR  2020-04-19 03:47:32 -54.80  -68.30
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     77.00       100          75        2.24
# 1     77.00        78          40       13.87
# 2     44.01        64           1        6.93
# 3     33.80        90          75       17.22
# 4     48.20        81          40        5.82

# %%
# Generate a new set of 1,500 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# %%
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 617

# %%
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cab30af5146fc2ee4a79713d706c5392

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# %%
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        try:
            city_rain = city_weather["rain"]["3h"]
        except KeyError:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["3h"]
        except KeyError:
            city_snot = 0
        
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain inches(last 3 hrs)": city_rain,
                          "Snow inches (last 3 hrs)": city_snow})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | gurupi
# City not found. Skipping...
# Processing Record 2 of Set 13 | erzin
# City not found. Skipping...
# Processing Record 3 of Set 13 | dikson
# City not found. Skipping...
# Processing Record 4 of Set 13 | sao mateus do sul
# City not found. Skipping...
# Processing Record 5 of Set 13 | butaritari
# City not found. Skipping...
# Processing Record 6 of Set 13 | qujing
# City not found. Skipping...
# Processing Record 7 of Set 13 | bluff
# City not found. Skipping...
# Processing Record 8 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 13 | upernavik
# City not found. Skipping...
# Processing Record 10 of Set 13 | belaya gora
# City not found. Skipping...
# Processing Record 11 of Set 13 | west bay
# City not found. Skipping...
# Processing Record 12 of Set 13 | tasiilaq
# Processing Record 13 of Set 13 | port alfred
# Processing Record 14 of Set 13 | kavieng
# Processing Record 15 of Set 13 | iqaluit
# Processing Record 16 of Set 13 | saint george
# Processing Record 17 of Set 13 | severo-kurilsk
# Processing Record 18 of Set 13 | hirara
# Processing Record 19 of Set 13 | esil
# Processing Record 20 of Set 13 | keuruu
# Processing Record 21 of Set 13 | yellowknife
# Processing Record 22 of Set 13 | port macquarie
# Processing Record 23 of Set 13 | atuona
# Processing Record 24 of Set 13 | busselton
# Processing Record 25 of Set 13 | ilulissat
# Processing Record 26 of Set 13 | zhuhai
# Processing Record 27 of Set 13 | rawson
# Processing Record 28 of Set 13 | hofn
# Processing Record 29 of Set 13 | magaria
# Processing Record 30 of Set 13 | tuktoyaktuk
# Processing Record 31 of Set 13 | minab
# Processing Record 32 of Set 13 | clyde river
# Processing Record 33 of Set 13 | mataura
# Processing Record 34 of Set 13 | bambous virieux
# Processing Record 35 of Set 13 | barrow
# Processing Record 36 of Set 13 | mountain home
# Processing Record 37 of Set 13 | cape town
# Processing Record 38 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 13 | tiksi
# Processing Record 40 of Set 13 | hermanus
# Processing Record 41 of Set 13 | albany
# Processing Record 42 of Set 13 | provideniya
# Processing Record 43 of Set 13 | tarakan
# Processing Record 44 of Set 13 | klaksvik
# Processing Record 45 of Set 13 | rikitea
# Processing Record 46 of Set 13 | port lincoln
# Processing Record 47 of Set 13 | punta arenas
# Processing Record 48 of Set 13 | traverse city
# Processing Record 49 of Set 13 | ushuaia
# Processing Record 50 of Set 13 | saint-philippe
# Processing Record 1 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 2 of Set 14 | kaitangata
# Processing Record 3 of Set 14 | kambove
# Processing Record 4 of Set 14 | usinsk
# Processing Record 5 of Set 14 | carnarvon
# Processing Record 6 of Set 14 | pontivy
# Processing Record 7 of Set 14 | thompson
# Processing Record 8 of Set 14 | georgetown
# Processing Record 9 of Set 14 | cayenne
# Processing Record 10 of Set 14 | mahebourg
# Processing Record 11 of Set 14 | havelock
# Processing Record 12 of Set 14 | east london
# Processing Record 13 of Set 14 | vaini
# Processing Record 14 of Set 14 | taybad
# Processing Record 15 of Set 14 | constitucion
# Processing Record 16 of Set 14 | chuy
# Processing Record 17 of Set 14 | deputatskiy
# Processing Record 18 of Set 14 | ola
# Processing Record 19 of Set 14 | ahtopol
# Processing Record 20 of Set 14 | padang
# Processing Record 21 of Set 14 | riverton
# Processing Record 22 of Set 14 | kodiak
# Processing Record 23 of Set 14 | snasa
# Processing Record 24 of Set 14 | zyryanka
# Processing Record 25 of Set 14 | sorland
# Processing Record 26 of Set 14 | esperance
# Processing Record 27 of Set 14 | ponta do sol
# Processing Record 28 of Set 14 | puerto ayora
# Processing Record 29 of Set 14 | kapaa
# Processing Record 30 of Set 14 | ponta delgada
# Processing Record 31 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 14 | jurado
# Processing Record 35 of Set 14 | jamestown
# Processing Record 36 of Set 14 | quthing
# Processing Record 37 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 38 of Set 14 | raudeberg
# Processing Record 39 of Set 14 | dhidhdhoo
# Processing Record 40 of Set 14 | yabrud
# Processing Record 41 of Set 14 | hilo
# Processing Record 42 of Set 14 | san patricio
# Processing Record 43 of Set 14 | sitka
# Processing Record 44 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 14 | coihaique
# Processing Record 46 of Set 14 | abalak
# Processing Record 47 of Set 14 | carutapera
# Processing Record 48 of Set 14 | mar del plata
# Processing Record 49 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 14 | fatehpur
# Processing Record 1 of Set 15 | rorvik
# Processing Record 2 of Set 15 | teruel
# Processing Record 3 of Set 15 | yining
# Processing Record 4 of Set 15 | lebu
# Processing Record 5 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 6 of Set 15 | hobart
# Processing Record 7 of Set 15 | qaanaaq
# Processing Record 8 of Set 15 | kargapolye
# City not found. Skipping...
# Processing Record 9 of Set 15 | sonoita
# Processing Record 10 of Set 15 | narsaq
# Processing Record 11 of Set 15 | muros
# Processing Record 12 of Set 15 | jiayuguan
# Processing Record 13 of Set 15 | airai
# Processing Record 14 of Set 15 | hostotipaquillo
# Processing Record 15 of Set 15 | warora
# Processing Record 16 of Set 15 | dayong
# Processing Record 17 of Set 15 | kiama
# Processing Record 18 of Set 15 | victoria
# Processing Record 19 of Set 15 | khatanga
# Processing Record 20 of Set 15 | west wendover
# Processing Record 21 of Set 15 | paamiut
# Processing Record 22 of Set 15 | hasaki
# Processing Record 23 of Set 15 | pisco
# Processing Record 24 of Set 15 | brae
# Processing Record 25 of Set 15 | govindgarh
# Processing Record 26 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 27 of Set 15 | teguldet
# Processing Record 28 of Set 15 | nanortalik
# Processing Record 29 of Set 15 | grand forks
# Processing Record 30 of Set 15 | saint-francois
# Processing Record 31 of Set 15 | severo-yeniseyskiy
# Processing Record 32 of Set 15 | sioux lookout
# Processing Record 33 of Set 15 | zyryanovsk
# Processing Record 34 of Set 15 | la ligua
# Processing Record 35 of Set 15 | waw
# Processing Record 36 of Set 15 | port blair
# Processing Record 37 of Set 15 | cidreira
# Processing Record 38 of Set 15 | nsanje
# Processing Record 39 of Set 15 | port moresby
# Processing Record 40 of Set 15 | salalah
# Processing Record 41 of Set 15 | dzhebariki-khaya
# Processing Record 42 of Set 15 | marfino
# Processing Record 43 of Set 15 | plettenberg bay
# Processing Record 44 of Set 15 | norman wells
# Processing Record 45 of Set 15 | columbus
# Processing Record 46 of Set 15 | sarande
# Processing Record 47 of Set 15 | nichinan
# Processing Record 48 of Set 15 | puro
# Processing Record 49 of Set 15 | eganville
# Processing Record 50 of Set 15 | willowmore
# Processing Record 1 of Set 16 | saint-joseph
# Processing Record 2 of Set 16 | saskylakh
# Processing Record 3 of Set 16 | gogrial
# Processing Record 4 of Set 16 | bredasdorp
# Processing Record 5 of Set 16 | linjiang
# Processing Record 6 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 16 | moshkovo
# Processing Record 8 of Set 16 | singkawang
# Processing Record 9 of Set 16 | nikolskoye
# Processing Record 10 of Set 16 | luderitz
# Processing Record 11 of Set 16 | lasa
# Processing Record 12 of Set 16 | balimo
# City not found. Skipping...
# Processing Record 13 of Set 16 | pahrump
# Processing Record 14 of Set 16 | guangyuan
# Processing Record 15 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 16 | zaraza
# Processing Record 17 of Set 16 | longyearbyen
# Processing Record 18 of Set 16 | aklavik
# Processing Record 19 of Set 16 | nazarovo
# Processing Record 20 of Set 16 | husavik
# Processing Record 21 of Set 16 | faya
# Processing Record 22 of Set 16 | phan thiet
# Processing Record 23 of Set 16 | adrar
# Processing Record 24 of Set 16 | lorengau
# Processing Record 25 of Set 16 | srikakulam
# Processing Record 26 of Set 16 | bethel
# Processing Record 27 of Set 16 | hervey bay
# Processing Record 28 of Set 16 | halifax
# Processing Record 29 of Set 16 | ekhabi
# Processing Record 30 of Set 16 | jalu
# Processing Record 31 of Set 16 | namibe
# Processing Record 32 of Set 16 | umm durman
# City not found. Skipping...
# Processing Record 33 of Set 16 | islamabad
# Processing Record 34 of Set 16 | beohari
# Processing Record 35 of Set 16 | meulaboh
# Processing Record 36 of Set 16 | stornoway
# Processing Record 37 of Set 16 | prince george
# Processing Record 38 of Set 16 | grindavik
# Processing Record 39 of Set 16 | juneau
# Processing Record 40 of Set 16 | castro
# Processing Record 41 of Set 16 | bokino
# Processing Record 42 of Set 16 | coquimbo
# Processing Record 43 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 16 | saldanha
# Processing Record 45 of Set 16 | kahului
# Processing Record 46 of Set 16 | vana-vigala
# Processing Record 47 of Set 16 | mehamn
# Processing Record 48 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 16 | yulara
# Processing Record 50 of Set 16 | angoram
# Processing Record 1 of Set 17 | komsomolskiy
# Processing Record 2 of Set 17 | khash
# Processing Record 3 of Set 17 | new norfolk
# Processing Record 4 of Set 17 | la palma
# Processing Record 5 of Set 17 | flin flon
# Processing Record 6 of Set 17 | mesaria
# Processing Record 7 of Set 17 | alugan
# Processing Record 8 of Set 17 | comodoro rivadavia
# Processing Record 9 of Set 17 | ribeira grande
# Processing Record 10 of Set 17 | charlottesville
# Processing Record 11 of Set 17 | isugod
# Processing Record 12 of Set 17 | rapid valley
# Processing Record 13 of Set 17 | belmonte
# Processing Record 14 of Set 17 | san cristobal
# Processing Record 15 of Set 17 | sisimiut
# Processing Record 16 of Set 17 | hami
# Processing Record 17 of Set 17 | zachagansk
# City not found. Skipping...
# Processing Record 18 of Set 17 | sept-iles
# Processing Record 19 of Set 17 | nokaneng
# Processing Record 20 of Set 17 | geraldton
# Processing Record 21 of Set 17 | lata
# Processing Record 22 of Set 17 | urdzhar
# City not found. Skipping...
# Processing Record 23 of Set 17 | vikhorevka
# Processing Record 24 of Set 17 | ahipara
# Processing Record 25 of Set 17 | laguna
# Processing Record 26 of Set 17 | ahero
# Processing Record 27 of Set 17 | tsaratanana
# Processing Record 28 of Set 17 | filingue
# Processing Record 29 of Set 17 | chongwe
# Processing Record 30 of Set 17 | alihe
# Processing Record 31 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 17 | amga
# Processing Record 33 of Set 17 | estevan
# Processing Record 34 of Set 17 | gao
# Processing Record 35 of Set 17 | kontagora
# Processing Record 36 of Set 17 | fortuna
# Processing Record 37 of Set 17 | kampot
# Processing Record 38 of Set 17 | dogondoutchi
# Processing Record 39 of Set 17 | kalavrita
# City not found. Skipping...
# Processing Record 40 of Set 17 | tiznit
# Processing Record 41 of Set 17 | general cepeda
# Processing Record 42 of Set 17 | concepcion
# Processing Record 43 of Set 17 | rafai
# Processing Record 44 of Set 17 | kutum
# Processing Record 45 of Set 17 | kenai
# Processing Record 46 of Set 17 | half moon bay
# Processing Record 47 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 17 | arzgir
# Processing Record 49 of Set 17 | cockburn town
# Processing Record 50 of Set 17 | rio gallegos
# Processing Record 1 of Set 18 | marawi
# Processing Record 2 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 18 | sovetskiy
# Processing Record 4 of Set 18 | hobyo
# Processing Record 5 of Set 18 | bunia
# Processing Record 6 of Set 18 | visby
# Processing Record 7 of Set 18 | panjab
# Processing Record 8 of Set 18 | nelson bay
# Processing Record 9 of Set 18 | gigmoto
# Processing Record 10 of Set 18 | dingle
# Processing Record 11 of Set 18 | popondetta
# Processing Record 12 of Set 18 | alofi
# Processing Record 13 of Set 18 | itoman
# Processing Record 14 of Set 18 | cherskiy
# Processing Record 15 of Set 18 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 16 of Set 18 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 18 | ust-barguzin
# Processing Record 18 of Set 18 | havre-saint-pierre
# Processing Record 19 of Set 18 | vila franca do campo
# Processing Record 20 of Set 18 | kanturk
# Processing Record 21 of Set 18 | kruisfontein
# Processing Record 22 of Set 18 | chokurdakh
# Processing Record 23 of Set 18 | vila velha
# Processing Record 24 of Set 18 | poum
# Processing Record 25 of Set 18 | pakxe
# Processing Record 26 of Set 18 | avarua
# Processing Record 27 of Set 18 | quatre cocos
# Processing Record 28 of Set 18 | dunedin
# Processing Record 29 of Set 18 | rio tinto
# Processing Record 30 of Set 18 | solnechnyy
# Processing Record 31 of Set 18 | pendleton
# Processing Record 32 of Set 18 | berlevag
# Processing Record 33 of Set 18 | fukue
# Processing Record 34 of Set 18 | pandan
# Processing Record 35 of Set 18 | tingrela
# City not found. Skipping...
# Processing Record 36 of Set 18 | bokoro
# Processing Record 37 of Set 18 | caravelas
# Processing Record 38 of Set 18 | sokoto
# Processing Record 39 of Set 18 | never
# Processing Record 40 of Set 18 | yirol
# City not found. Skipping...
# Processing Record 41 of Set 18 | tilik
# Processing Record 42 of Set 18 | tuatapere
# Processing Record 43 of Set 18 | sterlibashevo
# Processing Record 44 of Set 18 | port elizabeth
# Processing Record 45 of Set 18 | benjamin aceval
# Processing Record 46 of Set 18 | general roca
# Processing Record 47 of Set 18 | dawei
# Processing Record 48 of Set 18 | vardo
# Processing Record 49 of Set 18 | tupik
# Processing Record 50 of Set 18 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 19 | wattegama
# Processing Record 2 of Set 19 | peniche
# Processing Record 3 of Set 19 | aitape
# Processing Record 4 of Set 19 | shenzhen
# Processing Record 5 of Set 19 | bilibino
# Processing Record 6 of Set 19 | karlskrona
# Processing Record 7 of Set 19 | ambikapur
# Processing Record 8 of Set 19 | pevek
# Processing Record 9 of Set 19 | nauta
# Processing Record 10 of Set 19 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 19 | lejanias
# Processing Record 12 of Set 19 | hithadhoo
# Processing Record 13 of Set 19 | ko samui
# Processing Record 14 of Set 19 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 19 | port-cartier
# Processing Record 16 of Set 19 | port hardy
# Processing Record 17 of Set 19 | katsuura
# Processing Record 18 of Set 19 | bilma
# Processing Record 19 of Set 19 | canavieiras
# Processing Record 20 of Set 19 | manali
# Processing Record 21 of Set 19 | jacareacanga
# Processing Record 22 of Set 19 | syasstroy
# Processing Record 23 of Set 19 | talaya
# Processing Record 24 of Set 19 | lano
# Processing Record 25 of Set 19 | padrauna
# Processing Record 26 of Set 19 | stromness
# Processing Record 27 of Set 19 | isangel
# Processing Record 28 of Set 19 | nabire
# Processing Record 29 of Set 19 | anadyr
# Processing Record 30 of Set 19 | balikpapan
# Processing Record 31 of Set 19 | kudat
# Processing Record 32 of Set 19 | hovd
# Processing Record 33 of Set 19 | lumphat
# Processing Record 34 of Set 19 | kushima
# Processing Record 35 of Set 19 | kulhudhuffushi
# Processing Record 36 of Set 19 | los llanos de aridane
# Processing Record 37 of Set 19 | mercedes
# Processing Record 38 of Set 19 | saint stephen
# Processing Record 39 of Set 19 | batagay
# Processing Record 40 of Set 19 | bathsheba
# Processing Record 41 of Set 19 | varnavino
# Processing Record 42 of Set 19 | changping
# Processing Record 43 of Set 19 | teya
# Processing Record 44 of Set 19 | shimoda
# Processing Record 45 of Set 19 | port-gentil
# Processing Record 46 of Set 19 | harwich
# Processing Record 47 of Set 19 | nouadhibou
# Processing Record 48 of Set 19 | mogadishu
# Processing Record 49 of Set 19 | touros
# Processing Record 50 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 20 | sao filipe
# Processing Record 2 of Set 20 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 20 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 20 | oxford
# Processing Record 5 of Set 20 | shache
# Processing Record 6 of Set 20 | mumford
# Processing Record 7 of Set 20 | santa rosa
# Processing Record 8 of Set 20 | derzhavinsk
# Processing Record 9 of Set 20 | maryborough
# Processing Record 10 of Set 20 | kamenskiy
# Processing Record 11 of Set 20 | kedrovyy
# Processing Record 12 of Set 20 | karratha
# Processing Record 13 of Set 20 | birao
# Processing Record 14 of Set 20 | waihi beach
# Processing Record 15 of Set 20 | kurilsk
# Processing Record 16 of Set 20 | boende
# Processing Record 17 of Set 20 | aquiraz
# Processing Record 18 of Set 20 | la ronge
# Processing Record 19 of Set 20 | dehloran
# Processing Record 20 of Set 20 | portland
# Processing Record 21 of Set 20 | oranjemund
# Processing Record 22 of Set 20 | alta floresta
# Processing Record 23 of Set 20 | verkhoyansk
# Processing Record 24 of Set 20 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 20 | prince rupert
# Processing Record 26 of Set 20 | shingu
# Processing Record 27 of Set 20 | fenelon falls
# Processing Record 28 of Set 20 | sorong
# Processing Record 29 of Set 20 | tete
# Processing Record 30 of Set 20 | lavrentiya
# Processing Record 31 of Set 20 | borogontsy
# Processing Record 32 of Set 20 | guicheng
# City not found. Skipping...
# Processing Record 33 of Set 20 | rio grande
# Processing Record 34 of Set 20 | kieta
# Processing Record 35 of Set 20 | angoche
# Processing Record 36 of Set 20 | chumikan
# Processing Record 37 of Set 20 | westport
# Processing Record 38 of Set 20 | kenitra
# Processing Record 39 of Set 20 | hamilton
# Processing Record 40 of Set 20 | arraial do cabo
# Processing Record 41 of Set 20 | huarmey
# Processing Record 42 of Set 20 | votorantim
# Processing Record 43 of Set 20 | alyangula
# Processing Record 44 of Set 20 | torbay
# Processing Record 45 of Set 20 | champerico
# Processing Record 46 of Set 20 | shiraz
# Processing Record 47 of Set 20 | obihiro
# Processing Record 48 of Set 20 | mana
# Processing Record 49 of Set 20 | okha
# Processing Record 50 of Set 20 | guerrero negro
# Processing Record 1 of Set 21 | ambalema
# Processing Record 2 of Set 21 | lompoc
# Processing Record 3 of Set 21 | mingguang
# Processing Record 4 of Set 21 | sao pedro da aldeia
# Processing Record 5 of Set 21 | sechelt
# Processing Record 6 of Set 21 | great yarmouth
# Processing Record 7 of Set 21 | itaueira
# Processing Record 8 of Set 21 | marystown
# Processing Record 9 of Set 21 | santiago
# Processing Record 10 of Set 21 | alibag
# Processing Record 11 of Set 21 | manoharpur
# Processing Record 12 of Set 21 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 21 | lagunas
# Processing Record 14 of Set 21 | manuk mangkaw
# Processing Record 15 of Set 21 | cabedelo
# Processing Record 16 of Set 21 | gualaquiza
# Processing Record 17 of Set 21 | kloulklubed
# Processing Record 18 of Set 21 | chihuahua
# Processing Record 19 of Set 21 | camacha
# Processing Record 20 of Set 21 | xining
# Processing Record 21 of Set 21 | faanui
# Processing Record 22 of Set 21 | bud
# Processing Record 23 of Set 21 | tupiza
# Processing Record 24 of Set 21 | ontario
# Processing Record 25 of Set 21 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 21 | chikoy
# City not found. Skipping...
# Processing Record 27 of Set 21 | athens
# Processing Record 28 of Set 21 | narino
# Processing Record 29 of Set 21 | aldan
# Processing Record 30 of Set 21 | acapulco
# Processing Record 31 of Set 21 | ciocarlia
# Processing Record 32 of Set 21 | yueyang
# Processing Record 33 of Set 21 | wageningen
# Processing Record 34 of Set 21 | noumea
# Processing Record 35 of Set 21 | sol-iletsk
# Processing Record 36 of Set 21 | rehoboth
# Processing Record 37 of Set 21 | te anau
# Processing Record 38 of Set 21 | uberaba
# Processing Record 39 of Set 21 | yerbogachen
# Processing Record 40 of Set 21 | pacific grove
# Processing Record 41 of Set 21 | henties bay
# Processing Record 42 of Set 21 | ambon
# Processing Record 43 of Set 21 | deniliquin
# Processing Record 44 of Set 21 | hualmay
# Processing Record 45 of Set 21 | malakal
# Processing Record 46 of Set 21 | swift current
# Processing Record 47 of Set 21 | road town
# Processing Record 48 of Set 21 | taltal
# Processing Record 49 of Set 21 | rayachoti
# Processing Record 50 of Set 21 | gboko
# Processing Record 1 of Set 22 | san luis
# Processing Record 2 of Set 22 | gdov
# Processing Record 3 of Set 22 | inuvik
# Processing Record 4 of Set 22 | stepnyak
# Processing Record 5 of Set 22 | beyla
# Processing Record 6 of Set 22 | mastic beach
# Processing Record 7 of Set 22 | jiazi
# Processing Record 8 of Set 22 | stropkov
# Processing Record 9 of Set 22 | suzhou
# Processing Record 10 of Set 22 | creel
# Processing Record 11 of Set 22 | broome
# Processing Record 12 of Set 22 | raduzhnyy
# Processing Record 13 of Set 22 | sicamous
# Processing Record 14 of Set 22 | shenjiamen
# Processing Record 15 of Set 22 | san vicente
# Processing Record 16 of Set 22 | baillif
# Processing Record 17 of Set 22 | walvis bay
# Processing Record 18 of Set 22 | goycay
# City not found. Skipping...
# Processing Record 19 of Set 22 | kampene
# Processing Record 20 of Set 22 | sangar
# Processing Record 21 of Set 22 | chacabuco
# Processing Record 22 of Set 22 | nannilam
# Processing Record 23 of Set 22 | coahuayana
# Processing Record 24 of Set 22 | leningradskiy
# Processing Record 25 of Set 22 | padilla
# Processing Record 26 of Set 22 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 22 | nantucket
# Processing Record 28 of Set 22 | lagoa
# Processing Record 29 of Set 22 | abu kamal
# Processing Record 30 of Set 22 | kukushtan
# Processing Record 31 of Set 22 | cabo san lucas
# Processing Record 32 of Set 22 | kayankulam
# Processing Record 33 of Set 22 | sao joao da barra
# Processing Record 34 of Set 22 | strezhevoy
# Processing Record 35 of Set 22 | okhotsk
# Processing Record 36 of Set 22 | cao bang
# Processing Record 37 of Set 22 | muisne
# Processing Record 38 of Set 22 | asau
# Processing Record 39 of Set 22 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 22 | ibra
# Processing Record 41 of Set 22 | santa flavia
# Processing Record 42 of Set 22 | iberia
# Processing Record 43 of Set 22 | magdeburg
# Processing Record 44 of Set 22 | kysyl-syr
# Processing Record 45 of Set 22 | tefe
# Processing Record 46 of Set 22 | stephenville crossing
# Processing Record 47 of Set 22 | tumpat
# Processing Record 48 of Set 22 | sahrak
# City not found. Skipping...
# Processing Record 49 of Set 22 | souillac
# Processing Record 50 of Set 22 | monrovia
# Processing Record 1 of Set 23 | serramanna
# Processing Record 2 of Set 23 | chitrakonda
# Processing Record 3 of Set 23 | lesnoy
# Processing Record 4 of Set 23 | makakilo city
# Processing Record 5 of Set 23 | kungurtug
# Processing Record 6 of Set 23 | ebolowa
# Processing Record 7 of Set 23 | russell
# Processing Record 8 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 23 | pingliang
# Processing Record 10 of Set 23 | najran
# Processing Record 11 of Set 23 | amalner
# Processing Record 12 of Set 23 | boddam
# Processing Record 13 of Set 23 | ouadda
# Processing Record 14 of Set 23 | hay river
# Processing Record 15 of Set 23 | bonavista
# Processing Record 16 of Set 23 | kathmandu
# Processing Record 17 of Set 23 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 23 | manosque
# Processing Record 19 of Set 23 | pucallpa
# Processing Record 20 of Set 23 | lufilufi
# Processing Record 21 of Set 23 | ostrovnoy
# Processing Record 22 of Set 23 | santa cruz do capibaribe
# Processing Record 23 of Set 23 | kvarkeno
# Processing Record 24 of Set 23 | sterling
# Processing Record 25 of Set 23 | susangerd
# Processing Record 26 of Set 23 | mount isa
# Processing Record 27 of Set 23 | porto novo
# Processing Record 28 of Set 23 | iquitos
# Processing Record 29 of Set 23 | mount gambier
# Processing Record 30 of Set 23 | itarema
# Processing Record 31 of Set 23 | naze
# Processing Record 32 of Set 23 | oksfjord
# Processing Record 33 of Set 23 | djibo
# Processing Record 34 of Set 23 | vila
# Processing Record 35 of Set 23 | buin
# Processing Record 36 of Set 23 | newport
# Processing Record 37 of Set 23 | pingzhuang
# Processing Record 38 of Set 23 | skiathos
# Processing Record 39 of Set 23 | samarai
# Processing Record 40 of Set 23 | suyan
# Processing Record 41 of Set 23 | hambantota
# Processing Record 42 of Set 23 | mantova
# Processing Record 43 of Set 23 | saint combs
# City not found. Skipping...
# Processing Record 44 of Set 23 | tambul
# City not found. Skipping...
# Processing Record 45 of Set 23 | victoria point
# Processing Record 46 of Set 23 | presidencia roque saenz pena
# Processing Record 47 of Set 23 | varhaug
# Processing Record 48 of Set 23 | mahibadhoo
# Processing Record 49 of Set 23 | gulbarga
# Processing Record 50 of Set 23 | yarmouth
# Processing Record 1 of Set 24 | yangjiang
# Processing Record 2 of Set 24 | buraydah
# Processing Record 3 of Set 24 | tautira
# Processing Record 4 of Set 24 | sistranda
# Processing Record 5 of Set 24 | ojinaga
# Processing Record 6 of Set 24 | kostomuksha
# Processing Record 7 of Set 24 | merauke
# Processing Record 8 of Set 24 | port hedland
# Processing Record 9 of Set 24 | carora
# Processing Record 10 of Set 24 | saint-paul
# Processing Record 11 of Set 24 | eidfjord
# Processing Record 12 of Set 24 | mezen
# Processing Record 13 of Set 24 | aykhal
# Processing Record 14 of Set 24 | crestview
# Processing Record 15 of Set 24 | saint-leu
# Processing Record 16 of Set 24 | aurillac
# Processing Record 17 of Set 24 | ballina
# Processing Record 18 of Set 24 | tortoli
# Processing Record 19 of Set 24 | bengkulu
# Processing Record 20 of Set 24 | lujan
# Processing Record 21 of Set 24 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 24 | betsiamites
# Processing Record 23 of Set 24 | acarau
# Processing Record 24 of Set 24 | chapais
# Processing Record 25 of Set 24 | asfi
# Processing Record 26 of Set 24 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 24 | beringovskiy
# Processing Record 28 of Set 24 | zhigansk
# Processing Record 29 of Set 24 | storsteinnes
# Processing Record 30 of Set 24 | rocha
# Processing Record 31 of Set 24 | baherden
# Processing Record 32 of Set 24 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 24 | abha
# Processing Record 34 of Set 24 | thinadhoo
# Processing Record 35 of Set 24 | buckeye
# Processing Record 36 of Set 24 | el dorado
# Processing Record 37 of Set 24 | tual
# Processing Record 38 of Set 24 | sihor
# Processing Record 39 of Set 24 | kiunga
# Processing Record 40 of Set 24 | diamantino
# Processing Record 41 of Set 24 | ilo
# Processing Record 42 of Set 24 | toora-khem
# Processing Record 43 of Set 24 | srednekolymsk
# Processing Record 44 of Set 24 | narasannapeta
# Processing Record 45 of Set 24 | xuddur
# Processing Record 46 of Set 24 | sokolo
# Processing Record 47 of Set 24 | okoneshnikovo
# Processing Record 48 of Set 24 | goderich
# Processing Record 49 of Set 24 | lujiang
# Processing Record 50 of Set 24 | dunshaughlin
# Processing Record 1 of Set 25 | shakhovskaya
# Processing Record 2 of Set 25 | tateyama
# Processing Record 3 of Set 25 | gold coast
# Processing Record 4 of Set 25 | olafsvik
# Processing Record 5 of Set 25 | yurya
# City not found. Skipping...
# Processing Record 6 of Set 25 | robertsport
# Processing Record 7 of Set 25 | conde
# Processing Record 8 of Set 25 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 25 | san quintin
# Processing Record 10 of Set 25 | soyo
# Processing Record 11 of Set 25 | ketchikan
# Processing Record 12 of Set 25 | bardsir
# Processing Record 13 of Set 25 | middle island
# Processing Record 14 of Set 25 | praya
# Processing Record 15 of Set 25 | cap malheureux
# Processing Record 16 of Set 25 | prescott valley
# Processing Record 17 of Set 25 | melilla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City Country                 Date    Lat     Lng  Max Temp  \
# 0           Tasiilaq      GL  2020-04-19 18:25:11  65.61  -37.64     33.80
# 1        Port Alfred      ZA  2020-04-19 18:20:38 -33.59   26.89     77.63
# 2            Kavieng      PG  2020-04-19 18:21:21  -2.57  150.80     83.61
# 3            Iqaluit      CA  2020-04-19 18:22:11  63.75  -68.51      1.40
# 4       Saint George      US  2020-04-19 18:24:58  37.10 -113.58     66.99
# ..               ...     ...                  ...    ...     ...       ...
# 551    Middle Island      US  2020-04-19 18:28:54  40.88  -72.94     57.00
# 552            Praya      CV  2020-04-19 18:28:54  14.92  -23.51     78.80
# 553   Cap Malheureux      MU  2020-04-19 18:25:28 -19.98   57.61     77.00
# 554  Prescott Valley      US  2020-04-19 18:28:00  34.59 -112.33     66.00
# 555          Melilla      ES  2020-04-19 18:26:01  35.29   -2.94     68.00
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 0          69          99       16.11          light snow
# 1          57          20       14.81          few clouds
# 2          71          23        4.18          few clouds
# 3          70           5        3.36           clear sky
# 4          42           1        3.36           clear sky
# ..        ...         ...         ...                 ...
# 551        47           1       16.11           clear sky
# 552        57          40       20.80    scattered clouds
# 553        83          75        9.17       broken clouds
# 554        38          75        9.06       broken clouds
# 555        63          48       19.46    scattered clouds
#
#      Rain inches(last 3 hrs)  Snow inches (last 3 hrs)
# 0                        0.0                      0.43
# 1                        0.0                      0.43
# 2                        0.0                      0.43
# 3                        0.0                      0.43
# 4                        0.0                      0.43
# ..                       ...                       ...
# 551                      0.0                      0.63
# 552                      0.0                      0.63
# 553                      0.0                      0.63
# 554                      0.0                      0.63
# 555                      0.0                      0.63
#
# [556 rows x 12 columns]

# %%
city_data_df.to_csv("WeatherPy_challenge.csv")

# %%
#How many cities have recorded rainfall?
city_rains= (city_data_df["Rain inches(last 3 hrs)"]!=0).sum()
city_rains
# Out:
# 85

# %%
#How many cities have recorded snow?
city_snows=(city_data_df["Snow inches (last 3 hrs)"]!=0).sum()
city_snows
# Out:
# 556
